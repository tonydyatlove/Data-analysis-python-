# %%
import pandas as pd

# %%
bookings = pd.read_csv('https://stepik.org/media/attachments/lesson/360344/bookings.csv', encoding='windows-1251', sep=';')

# %%
bookings_head = bookings.iloc[:7]

# %%
bookings_head
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
bookings.dtypes
# Out:
# Hotel                         object
# Is Canceled                    int64
# Lead Time                      int64
# arrival full date             object
# Arrival Date Year              int64
# Arrival Date Month            object
# Arrival Date Week Number       int64
# Arrival Date Day of Month      int64
# Stays in Weekend nights        int64
# Stays in week nights           int64
# stays total nights             int64
# Adults                         int64
# Children                     float64
# Babies                         int64
# Meal                          object
# Country                       object
# Reserved Room Type            object
# Assigned room type            object
# customer type                 object
# Reservation Status            object
# Reservation status_date       object
# dtype: object

# %%
bookings.columns = bookings.columns.str.replace(' ', '_')

# %%
bookings.dtypes
# Out:
# Hotel                         object
# Is_Canceled                    int64
# Lead_Time                      int64
# arrival_full_date             object
# Arrival_Date_Year              int64
# Arrival_Date_Month            object
# Arrival_Date_Week_Number       int64
# Arrival_Date_Day_of_Month      int64
# Stays_in_Weekend_nights        int64
# Stays_in_week_nights           int64
# stays_total_nights             int64
# Adults                         int64
# Children                     float64
# Babies                         int64
# Meal                          object
# Country                       object
# Reserved_Room_Type            object
# Assigned_room_type            object
# customer_type                 object
# Reservation_Status            object
# Reservation_status_date       object
# dtype: object

# %%
bookings.columns = bookings.columns.str.lower()

# %%
bookings.dtypes
# Out:
# hotel                         object
# is_canceled                    int64
# lead_time                      int64
# arrival_full_date             object
# arrival_date_year              int64
# arrival_date_month            object
# arrival_date_week_number       int64
# arrival_date_day_of_month      int64
# stays_in_weekend_nights        int64
# stays_in_week_nights           int64
# stays_total_nights             int64
# adults                         int64
# children                     float64
# babies                         int64
# meal                          object
# country                       object
# reserved_room_type            object
# assigned_room_type            object
# customer_type                 object
# reservation_status            object
# reservation_status_date       object
# dtype: object

# %%
bookings.head
# Out:
# <bound method NDFrame.head of                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
bookings_by_countries = bookings.query('is_canceled == 0').groupby(['country'], as_index = False).aggregate({'is_canceled': 'count'}).sort_values('is_canceled', ascending = False)

# %%
bookings_by_countries
# Out:
#     country  is_canceled
# 125     PRT        21071
# 57      GBR         9676
# 54      FRA         8481
# 50      ESP         6391
# 42      DEU         6069
# ..      ...          ...
# 138     SMR            1
# 101     MLI            1
# 136     SLE            1
# 94      MAC            1
# 122     PLW            1
#
# [165 rows x 2 columns]

# %%
stays_total_nights_average = bookings.loc[bookings['hotel'] == 'Resort Hotel', 'stays_total_nights'].mean().round(2)

# %%
stays_total_nights_average
# Out:
# 4.32

# %%
len(bookings.loc[bookings.assigned_room_type != bookings.reserved_room_type])
# Out:
# 14917

# %%
most_popular_month = bookings.loc[bookings['arrival_date_year'] == 2016, 'arrival_date_month'].value_counts()

# %%
most_popular_month
# Out:
# October      6203
# May          5478
# April        5428
# September    5394
# June         5292
# August       5063
# March        4824
# July         4572
# November     4454
# February     3891
# December     3860
# January      2248
# Name: arrival_date_month, dtype: int64

# %%
bookings.query('is_canceled == 1').groupby(['arrival_date_year', 'arrival_date_month'], as_index=False).aggregate({'is_canceled': 'count'}).sort_values('is_canceled', ascending=False)
# Out:
#     arrival_date_year arrival_date_month  is_canceled
# 25               2017                May         2762
# 16               2016            October         2514
# 18               2017              April         2463
# 23               2017               June         2439
# 12               2016               June         2096
# 5                2015          September         2094
# 6                2016              April         2061
# 17               2016          September         2022
# 22               2017               July         1984
# 14               2016                May         1915
# 7                2016             August         1825
# 19               2017             August         1816
# 4                2015            October         1732
# 24               2017              March         1672
# 15               2016           November         1636
# 0                2015             August         1598
# ...

# %%
bookings['adults'].mean()
# Out:
# 1.8564033838679956

# %%
bookings['children'].mean()
# Out:
# 0.10388990333874994

# %%
bookings['babies'].mean()
# Out:
# 0.007948739425412514

# %%
col_list = ['children', 'babies']

# %%
bookings['total_kids'] = bookings['children'] + bookings['babies']

# %%
bookings.loc[bookings['hotel'] == 'Resort Hotel', 'total_kids'].mean().round(2)
# Out:
# 0.14

# %%
bookings.loc[bookings['hotel'] == 'City Hotel', 'total_kids'].mean().round(2)
# Out:
# 0.1

# %%
bookings.dtypes
# Out:
# hotel                         object
# is_canceled                    int64
# lead_time                      int64
# arrival_full_date             object
# arrival_date_year              int64
# arrival_date_month            object
# arrival_date_week_number       int64
# arrival_date_day_of_month      int64
# stays_in_weekend_nights        int64
# stays_in_week_nights           int64
# stays_total_nights             int64
# adults                         int64
# children                     float64
# babies                         int64
# meal                          object
# country                       object
# reserved_room_type            object
# assigned_room_type            object
# customer_type                 object
# reservation_status            object
# reservation_status_date       object
# total_kids                   float64
# dtype: object

# %%
have_kids = []
for i in range(len(bookings.total_kids)):
    if bookings.total_kids[i] > 0:
        have_kids.append('True')
    else:
        have_kids.append('False')

# %%
have_kids
# Out:
# ['False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'True',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
# ...

# %%
bookings['has_kids'] = have_kids

# %%
bookings.has_kids
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Name: has_kids, Length: 119390, dtype: object

# %%
amount_of_canceled = bookings.loc[bookings['is_canceled'] == 1, 'is_canceled'].count()

# %%
amount_of_canceled
# Out:
# 44224

# %%
bookings.has_kids.describe()
# Out:
# count     119390
# unique         2
# top        False
# freq      110058
# Name: has_kids, dtype: object

# %%
is_canceled_and_has_kids = len(bookings[(bookings['has_kids'] == 'True') & (bookings['is_canceled'] == 1)])

# %%
is_canceled_and_has_kids
# Out:
# 3259

# %%
is_canceled_and_no_kids = len(bookings[(bookings['has_kids'] == 'False') & (bookings['is_canceled'] == 1)])

# %%
is_canceled_and_no_kids
# Out:
# 40965

# %%
churn_rate_has_kids = (is_canceled_and_has_kids / amount_of_canceled).round(2)

# %%
churn_rate_has_kids
# Out:
# 0.07

# %%
churn_rate_no_kids = (is_canceled_and_no_kids / amount_of_canceled).round(4)

# %%
churn_rate_no_kids
# Out:
# 0.9263

# %%
amount_has_kids = len(bookings[(bookings['has_kids'] == 'True')])

# %%
amount_has_kids
# Out:
# 9332

# %%
is_canceled_and_has_kids / amount_has_kids
# Out:
# 0.3492284612087441

# %%
amount_no_kids = len(bookings[(bookings['has_kids'] == 'False')])

# %%
amount_no_kids
# Out:
# 110058

# %%
is_canceled_and_no_kids / amount_no_kids
# Out:
# 0.37221283323338605
